# %%
from evalb import evalb

# %%
en = open("corpus/cleaned_wiki/train.80.en.tree").read()
sen = open("corpus/cleaned_wiki/train.80.sen.tree").read()

# %%
en = en.split("\n\n")
sen = sen.split("\n\n")

# %%
ev = evalb(en,sen)
# Out:
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _
# _

# %%
ev.parsed
# Out:
# [[('ROOT', (0, 5)),
#   ('S', (0, 5)),
#   ('NP', (0, 1)),
#   ('PRP', (0, 1)),
#   ('VP', (1, 4)),
#   ('VBD', (1, 2)),
#   ('PP', (2, 4)),
#   ('IN', (2, 3)),
#   ('NP', (3, 4)),
#   ('CD', (3, 4)),
#   ('.', (4, 5))],
#  [('ROOT', (0, 24)),
#   ('S', (0, 24)),
#   ('NP', (0, 1)),
#   ('NNP', (0, 1)),
#   ('VP', (1, 23)),
#   ('VBD', (1, 2)),
#   ('VP', (2, 23)),
#   ('VBN', (2, 3)),
#   ('PP', (3, 7)),
#   ('TO', (3, 4)),
#   ('NP', (4, 7)),
#   ('NP', (4, 5)),
#   ('NNP', (4, 5)),
#   ('PP', (5, 7)),
#   ('IN', (5, 6)),
#   ('NP', (6, 7)),
#   ('CD', (6, 7)),
#   ('PP', (7, 23)),
#   ('IN', (7, 8)),
#   ('NP', (8, 23)),
#   ('NP', (8, 12)),
#   ('DT', (8, 9)),
#   ('JJ', (9, 10)),
#   ('NN', (1, 11)),
#   ('NNP', (1, 12)),
#   ('PP', (1, 23)),
#   ('IN', (1, 13)),
#   ('NP', (1, 23)),
#   ('NP', (1, 18)),
#   ('NP', (1, 14)),
#   ('NNP', (1, 14)),
#   ('PRN', (1, 18)),
#   ('-LRB-', (1, 15)),
#   ('NP', (1, 17)),
#   ('NNP', (1, 16)),
#   ('NNP', (1, 17)),
# ...
